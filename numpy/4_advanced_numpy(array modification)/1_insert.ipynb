# %%
import numpy as np
# np.insert(array, index, value, axis)

# %%
arr=np.array([10,20,30,40,50,60])
print(arr)
new_arr=np.insert(arr,6,70)
print(new_arr)
# Out:
# [10 20 30 40 50 60]
# [10 20 30 40 50 60 70]
