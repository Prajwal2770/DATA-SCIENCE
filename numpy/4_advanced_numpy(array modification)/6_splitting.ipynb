# %%
import numpy as np

# %% [markdown]
# # syntax
# np.split(arrname,no of parts)

# %%
arr=np.array([10,20,30,40,50,60])
print(np.split(arr,2)) #split into equal parts
# Out:
# [array([10, 20, 30]), array([40, 50, 60])]
