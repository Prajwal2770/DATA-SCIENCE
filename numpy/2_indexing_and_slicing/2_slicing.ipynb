# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50,60])
print(arr[1:5])
print(arr[:4])
print(arr[::2])
print(arr[::-1])
# Out:
# [20 30 40 50]
# [10 20 30 40]
# [10 30 50]
# [60 50 40 30 20 10]
